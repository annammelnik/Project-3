# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.eldenring
collection = db.weaponsummary

# %%
# URL of page to be scraped
url = 'https://eldenring.wiki.fextralife.com/Weapons+Comparison+Tables'
# retrieve page with the reqests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html5lib')

# %%
thead = soup.find('thead')
ths = thead.find_all('th')
keys = []
for th in ths:
    if th.text.strip() not in keys:
        keys.append(th.text.strip())
    else:
        keys.append("def-" + th.text.strip())
print(keys)
# Out:
# ['Weapon', 'Type', 'Phy', 'Mag', 'Fir', 'Lit', 'Hol', 'Cri', 'Sta', 'Str', 'Dex', 'Int', 'Fai', 'Arc', 'Any', 'def-Phy', 'def-Mag', 'def-Fir', 'def-Lit', 'def-Hol', 'Bst', 'Rst', 'Wgt', 'Upgrade']

# %%
# create function for replacing values for cleaning the data
def replace_values(list_to_replace, item_to_replace, item_to_replace_with):
    return [item_to_replace_with if item == item_to_replace else item for item in list_to_replace]

# %%
tbody = soup.find('tbody')
trs = tbody.find_all('tr')
for tr in trs:
    data = []
    post ={}
    tds = tr.find_all('td')
    for td in tds:
        data.append(td.text)
        data = replace_values(data, "-", "0")
    for key in keys:
        for value in data:
            post[key] = value
            data.remove(value)
            break
    int_values = ['Bst','Cri','Fir','Hol','Lit','Mag','Phy','Rst','Sta','Wgt']
    for v in int_values:
        post[v] = float(post[v])
    collection.insert_one(post)
    print(post)
# Out:
# {'Weapon': 'Academy Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': 43.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963407')}
# {'Weapon': "Alabaster Lord's Sword", 'Type': 'Greatsword', 'Phy': 313.0, 'Mag': 93.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 126.0, 'Str': 'B', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '41', 'def-Mag': '33', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 33.0, 'Rst': 19.0, 'Wgt': 8.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963408')}
# {'Weapon': 'Albinauric Bow', 'Type': 'Bow', 'Phy': 200.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 60.0, 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 4.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963409')}
# {'Weapon': 'Albinauric Staff', 'Type': 'Glintstone Staff', 'Phy': 29.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 38.0, 'Str': 'D', 'Dex': '0', 'Int': 'B', 'Fai': '0', 'Arc': 'S', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': 14.0, 'Rst': 9.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796340a')}
# {'Weapon': 'Antspur Rapier', 'Type': 'Thrusting Sword', 'Phy': 240.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 62.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 25.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796340b')}
# {'Weapon': 'Arbalest', 'Type': 'Crossbow', 'Phy': 308.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 68.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 6.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796340c')}
# {'Weapon': "Astrologer's Staff", 'Type': 'Glintstone Staff', 'Phy': 43.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796340d')}
# {'Weapon': 'Axe of Godfrey', 'Type': 'Colossal Weapon', 'Phy': 404.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '45', 'def-Fir': '45', 'def-Lit': '45', 'def-Hol': '45', 'Bst': 40.0, 'Rst': 25.0, 'Wgt': 18.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796340e')}
# {'Weapon': 'Axe of Godrick', 'Type': 'Greataxe', 'Phy': 347.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 35.0, 'Rst': 20.0, 'Wgt': 11.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796340f')}
# {'Weapon': "Azur's Glintstone Staff", 'Type': 'Glintstone Staff', 'Phy': 58.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 42.0, 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963410')}
# {'Weapon': "Bandit's Curved Sword", 'Type': 'Curved Sword', 'Phy': 289.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 98.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 36.0, 'Rst': 12.0, 'Wgt': 5.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963411')}
# {'Weapon': "Banished Knight's Greatsword", 'Type': 'Greatsword', 'Phy': 347.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 132.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 43.0, 'Rst': 21.0, 'Wgt': 10.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963412')}
# {'Weapon': "Banished Knight's Halberd", 'Type': 'Halberd', 'Phy': 306.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 122.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 15.0, 'Wgt': 8.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963413')}
# {'Weapon': 'Bastard Sword', 'Type': 'Greatsword', 'Phy': 338.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 126.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 20.0, 'Wgt': 9.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963414')}
# {'Weapon': "Bastard's Stars", 'Type': 'Flail', 'Phy': 159.0, 'Mag': 191.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 106.0, 'Str': 'E', 'Dex': 'C', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '32', 'def-Mag': '48', 'def-Fir': '24', 'def-Lit': '24', 'def-Hol': '24', 'Bst': 20.0, 'Rst': 15.0, 'Wgt': 5.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963415')}
# {'Weapon': 'Battle Axe', 'Type': 'Axe', 'Phy': 301.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 112.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 37.0, 'Rst': 15.0, 'Wgt': 4.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963416')}
# {'Weapon': 'Battle Hammer', 'Type': 'Great Hammer', 'Phy': 320.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 194.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 43.0, 'Rst': 21.0, 'Wgt': 10.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963417')}
# {'Weapon': 'Beast-Repellent Torch', 'Type': 'Torch', 'Phy': 142.0, 'Mag': 0.0, 'Fir': 254.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '17', 'def-Fir': '28', 'def-Lit': '17', 'def-Hol': '17', 'Bst': 22.0, 'Rst': 14.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963418')}
# {'Weapon': 'Beastclaw Greathammer', 'Type': 'Great Hammer', 'Phy': 284.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 183.0, 'Cri': 100.0, 'Sta': 182.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '45', 'Bst': 35.0, 'Rst': 20.0, 'Wgt': 9.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963419')}
# {'Weapon': "Beastman's Cleaver", 'Type': 'Curved Greatsword', 'Phy': 350.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 164.0, 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '62', 'def-Mag': '43', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': 51.0, 'Rst': 25.0, 'Wgt': 16.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796341a')}
# {'Weapon': "Beastman's Curved Sword", 'Type': 'Curved Sword', 'Phy': 276.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 98.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 32.0, 'Rst': 11.0, 'Wgt': 4.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796341b')}
# {'Weapon': 'Black Bow', 'Type': 'Bow', 'Phy': 171.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 60.0, 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796341c')}
# {'Weapon': 'Black Knife', 'Type': 'Dagger', 'Phy': 161.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 159.0, 'Cri': 110.0, 'Sta': 56.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '26', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '42', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 2.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796341d')}
# {'Weapon': 'Blade of Calling', 'Type': 'Dagger', 'Phy': 173.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 105.0, 'Cri': 110.0, 'Sta': 56.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '31', 'def-Mag': '18', 'def-Fir': '18', 'def-Lit': '18', 'def-Hol': '30', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 1.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796341e')}
# {'Weapon': 'Blasphemous Blade', 'Type': 'Greatsword', 'Phy': 296.0, 'Mag': 0.0, 'Fir': 191.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 138.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '56', 'def-Mag': '39', 'def-Fir': '54', 'def-Lit': '39', 'def-Hol': '39', 'Bst': 42.0, 'Rst': 24.0, 'Wgt': 13.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796341f')}
# {'Weapon': 'Bloodhound Claws', 'Type': 'Claw', 'Phy': 230.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 110.0, 'Sta': 78.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(60)', 'def-Phy': '38', 'def-Mag': '22', 'def-Fir': '22', 'def-Lit': '22', 'def-Hol': '22', 'Bst': 26.0, 'Rst': 11.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963420')}
# {'Weapon': "Bloodhound's Fang", 'Type': 'Curved Greatsword', 'Phy': 345.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 122.0, 'Str': 'C', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 36.0, 'Rst': 21.0, 'Wgt': 11.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963421')}
# {'Weapon': 'Bloodstained Dagger', 'Type': 'Dagger', 'Phy': 198.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 110.0, 'Sta': 60.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(38)', 'def-Phy': '36', 'def-Mag': '21', 'def-Fir': '21', 'def-Lit': '21', 'def-Hol': '21', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 2.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963422')}
# {'Weapon': 'Bloody Helice', 'Type': 'Heavy Thrusting Sword', 'Phy': 296.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'E', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': 'B', 'Any': '(55)', 'def-Phy': '57', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': 34.0, 'Rst': 17.0, 'Wgt': 8.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963423')}
# {'Weapon': 'Bolt of Gransax', 'Type': 'Spear', 'Phy': 240.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 154.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 88.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '47', 'def-Hol': '31', 'Bst': 40.0, 'Rst': 20.0, 'Wgt': 8.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963424')}
# {'Weapon': 'Brick Hammer', 'Type': 'Great Hammer', 'Phy': 298.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 218.0, 'Str': 'A', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '57', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': 48.0, 'Rst': 23.0, 'Wgt': 12.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963425')}
# {'Weapon': 'Broadsword', 'Type': 'Straight Sword', 'Phy': 286.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 37.0, 'Rst': 15.0, 'Wgt': 4.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963426')}
# {'Weapon': 'Butchering Knife', 'Type': 'Greataxe', 'Phy': 328.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 37.0, 'Rst': 18.0, 'Wgt': 8.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963427')}
# {'Weapon': 'Caestus', 'Type': 'Fist', 'Phy': 220.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 100.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '20', 'def-Hol': '20', 'Bst': 24.0, 'Rst': 10.0, 'Wgt': 1.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963428')}
# {'Weapon': 'Cane Sword', 'Type': 'Straight Sword', 'Phy': 235.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 86.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '41', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 32.0, 'Rst': 13.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963429')}
# {'Weapon': 'Carian Glintblade Staff', 'Type': 'Glintstone Staff', 'Phy': 38.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 38.0, 'Str': 'D', 'Dex': 'D', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': 14.0, 'Rst': 9.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796342a')}
# {'Weapon': 'Carian Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': 43.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796342b')}
# {'Weapon': "Carian Knight's Sword", 'Type': 'Straight Sword', 'Phy': 215.0, 'Mag': 215.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': 'C', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '52', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '26', 'Bst': 31.0, 'Rst': 15.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796342c')}
# {'Weapon': 'Carian Regal Scepter', 'Type': 'Glintstone Staff', 'Phy': 58.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'D', 'Dex': 'D', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796342d')}
# {'Weapon': "Celebrant's Cleaver", 'Type': 'Axe', 'Phy': 291.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 112.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 37.0, 'Rst': 15.0, 'Wgt': 4.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796342e')}
# {'Weapon': "Celebrant's Rib-Rake", 'Type': 'Spear', 'Phy': 267.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 68.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '40', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': 36.0, 'Rst': 15.0, 'Wgt': 5.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796342f')}
# {'Weapon': "Celebrant's Sickle", 'Type': 'Dagger', 'Phy': 193.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 56.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '20', 'def-Hol': '20', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 1.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963430')}
# {'Weapon': "Celebrant's Skull", 'Type': 'Great Hammer', 'Phy': 338.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 182.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '34', 'def-Fir': '34', 'def-Lit': '34', 'def-Hol': '34', 'Bst': 40.0, 'Rst': 19.0, 'Wgt': 8.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963431')}
# {'Weapon': 'Chainlink Flail', 'Type': 'Flail', 'Phy': 267.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 122.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '43', 'def-Mag': '28', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': 28.0, 'Rst': 18.0, 'Wgt': 8.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963432')}
# {'Weapon': 'Cinquedea', 'Type': 'Dagger', 'Phy': 240.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 68.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '43', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': 18.0, 'Rst': 12.0, 'Wgt': 3.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963433')}
# {'Weapon': 'Cipher Pata', 'Type': 'Fist', 'Phy': 0.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 208.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'A', 'Arc': '0', 'Any': '0', 'def-Phy': '9', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '61', 'Bst': 19.0, 'Rst': 9.0, 'Wgt': 0.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963434')}
# {'Weapon': 'Clawmark Seal', 'Type': 'Sacred Seal', 'Phy': 54.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 1.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963435')}
# {'Weapon': "Clayman's Harpoon", 'Type': 'Spear', 'Phy': 242.0, 'Mag': 156.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 80.0, 'Str': 'C', 'Dex': 'E', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '38', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': 39.0, 'Rst': 16.0, 'Wgt': 5.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963436')}
# {'Weapon': 'Claymore', 'Type': 'Greatsword', 'Phy': 338.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 126.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 20.0, 'Wgt': 9.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963437')}
# {'Weapon': "Cleanrot Knight's Sword", 'Type': 'Thrusting Sword', 'Phy': 267.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 66.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '51', 'def-Mag': '34', 'def-Fir': '34', 'def-Lit': '34', 'def-Hol': '34', 'Bst': 27.0, 'Rst': 11.0, 'Wgt': 4.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963438')}
# {'Weapon': 'Cleanrot Spear', 'Type': 'Spear', 'Phy': 249.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 161.0, 'Cri': 100.0, 'Sta': 80.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '38', 'Bst': 33.0, 'Rst': 16.0, 'Wgt': 5.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963439')}
# {'Weapon': 'Clinging Bone', 'Type': 'Fist', 'Phy': 196.0, 'Mag': 58.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': 'C', 'Any': '0', 'def-Phy': '31', 'def-Mag': '36', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': 21.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796343a')}
# {'Weapon': 'Club', 'Type': 'Hammer', 'Phy': 252.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 102.0, 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '41', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 32.0, 'Rst': 13.0, 'Wgt': 3.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796343b')}
# {'Weapon': 'Coded Sword', 'Type': 'Straight Sword', 'Phy': 0.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 208.0, 'Cri': 100.0, 'Sta': 76.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'A', 'Arc': '0', 'Any': '0', 'def-Phy': '13', 'def-Mag': '22', 'def-Fir': '22', 'def-Lit': '22', 'def-Hol': '58', 'Bst': 27.0, 'Rst': 13.0, 'Wgt': 2.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796343c')}
# {'Weapon': "Commander's Standard", 'Type': 'Halberd', 'Phy': 338.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 136.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '58', 'def-Mag': '41', 'def-Fir': '41', 'def-Lit': '41', 'def-Hol': '41', 'Bst': 41.0, 'Rst': 17.0, 'Wgt': 11.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796343d')}
# {'Weapon': 'Composite Bow', 'Type': 'Light Bow', 'Phy': 159.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796343e')}
# {'Weapon': 'Cranial Vessel Candlestand', 'Type': 'Great Hammer', 'Phy': 240.0, 'Mag': 0.0, 'Fir': 240.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 190.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '37', 'def-Fir': '51', 'def-Lit': '37', 'def-Hol': '37', 'Bst': 40.0, 'Rst': 23.0, 'Wgt': 12.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796343f')}
# {'Weapon': "Crepus's Black-Key Crossbow", 'Type': 'Crossbow', 'Phy': 238.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 64.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 5.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963440')}
# {'Weapon': 'Crescent Moon Axe', 'Type': 'Greataxe', 'Phy': 357.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 156.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 43.0, 'Rst': 21.0, 'Wgt': 12.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963441')}
# {'Weapon': 'Cross-Naginata', 'Type': 'Spear', 'Phy': 298.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 88.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '52', 'def-Mag': '32', 'def-Fir': '32', 'def-Lit': '32', 'def-Hol': '32', 'Bst': 46.0, 'Rst': 19.0, 'Wgt': 8.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963442')}
# {'Weapon': 'Crystal Knife', 'Type': 'Dagger', 'Phy': 200.0, 'Mag': 129.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 62.0, 'Str': 'C', 'Dex': 'D', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '32', 'def-Mag': '31', 'def-Fir': '18', 'def-Lit': '18', 'def-Hol': '18', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 2.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963443')}
# {'Weapon': 'Crystal Spear', 'Type': 'Spear', 'Phy': 269.0, 'Mag': 80.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 80.0, 'Str': 'D', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '33', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '26', 'Bst': 33.0, 'Rst': 16.0, 'Wgt': 5.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963444')}
# {'Weapon': 'Crystal Staff', 'Type': 'Glintstone Staff', 'Phy': 75.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 46.0, 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '28', 'def-Mag': '17', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': 17.0, 'Rst': 11.0, 'Wgt': 4.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963445')}
# {'Weapon': 'Crystal Sword', 'Type': 'Straight Sword', 'Phy': 259.0, 'Mag': 166.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 98.0, 'Str': 'C', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '44', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': 33.0, 'Rst': 16.0, 'Wgt': 4.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963446')}
# {'Weapon': 'Curved Club', 'Type': 'Hammer', 'Phy': 279.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 106.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': 36.0, 'Rst': 15.0, 'Wgt': 5.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963447')}
# {'Weapon': 'Curved Great Club', 'Type': 'Great Hammer', 'Phy': 355.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 194.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 43.0, 'Rst': 21.0, 'Wgt': 10.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963448')}
# {'Weapon': 'Dagger', 'Type': 'Dagger', 'Phy': 181.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 130.0, 'Sta': 60.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '20', 'def-Hol': '20', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 1.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963449')}
# {'Weapon': 'Dark Moon Greatsword', 'Type': 'Greatsword', 'Phy': 200.0, 'Mag': 240.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 126.0, 'Str': 'D', 'Dex': 'D', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '42', 'def-Mag': '63', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 36.0, 'Rst': 21.0, 'Wgt': 10.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796344a')}
# {'Weapon': 'Death Ritual Spear', 'Type': 'Spear', 'Phy': 242.0, 'Mag': 156.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 110.0, 'Sta': 84.0, 'Str': 'D', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '42', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 36.0, 'Rst': 18.0, 'Wgt': 6.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796344b')}
# {'Weapon': "Death's Poker", 'Type': 'Greatsword', 'Phy': 301.0, 'Mag': 88.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 116.0, 'Str': 'C', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '(65)', 'def-Phy': '46', 'def-Mag': '39', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 33.0, 'Rst': 19.0, 'Wgt': 8.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796344c')}
# {'Weapon': "Demi-Human Queen's Staff", 'Type': 'Glintstone Staff', 'Phy': 54.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796344d')}
# {'Weapon': "Devourer's Scepter", 'Type': 'Great Hammer', 'Phy': 262.0, 'Mag': 0.0, 'Fir': 169.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 154.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '45', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 35.0, 'Rst': 20.0, 'Wgt': 11.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796344e')}
# {'Weapon': "Digger's Staff", 'Type': 'Glintstone Staff', 'Phy': 66.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 46.0, 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '28', 'def-Mag': '17', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': 17.0, 'Rst': 11.0, 'Wgt': 4.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796344f')}
# {'Weapon': 'Dismounter', 'Type': 'Curved Greatsword', 'Phy': 338.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 122.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 20.0, 'Wgt': 10.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963450')}
# {'Weapon': 'Dragon Communion Seal', 'Type': 'Sacred Seal', 'Phy': 61.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'B', 'Arc': 'S', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 0.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963451')}
# {'Weapon': 'Dragon Greatclaw', 'Type': 'Colossal Weapon', 'Phy': 294.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 191.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '52', 'def-Hol': '40', 'Bst': 38.0, 'Rst': 23.0, 'Wgt': 16.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963452')}
# {'Weapon': 'Dragon Halberd', 'Type': 'Halberd', 'Phy': 330.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 136.0, 'Str': 'B', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '37', 'def-Fir': '37', 'def-Lit': '50', 'def-Hol': '37', 'Bst': 39.0, 'Rst': 16.0, 'Wgt': 10.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963453')}
# {'Weapon': "Dragon King's Cragblade", 'Type': 'Heavy Thrusting Sword', 'Phy': 225.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 144.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 98.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '46', 'def-Mag': '32', 'def-Fir': '32', 'def-Lit': '46', 'def-Hol': '32', 'Bst': 34.0, 'Rst': 17.0, 'Wgt': 8.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963454')}
# {'Weapon': 'Dragonscale Blade', 'Type': 'Katana', 'Phy': 269.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '50', 'def-Hol': '25', 'Bst': 30.0, 'Rst': 15.0, 'Wgt': 5.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963455')}
# {'Weapon': 'Duelist Greataxe', 'Type': 'Colossal Weapon', 'Phy': 416.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 156.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '63', 'def-Mag': '47', 'def-Fir': '47', 'def-Lit': '47', 'def-Hol': '47', 'Bst': 50.0, 'Rst': 26.0, 'Wgt': 20.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963456')}
# {'Weapon': 'Eclipse Shotel', 'Type': 'Curved Sword', 'Phy': 188.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 188.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '50', 'Bst': 25.0, 'Rst': 10.0, 'Wgt': 3.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963457')}
# {'Weapon': "Eleonora's Poleblade", 'Type': 'Twinblade', 'Phy': 176.0, 'Mag': 0.0, 'Fir': 176.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 84.0, 'Str': 'E', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': 'D', 'Any': '(83)', 'def-Phy': '33', 'def-Mag': '23', 'def-Fir': '47', 'def-Lit': '23', 'def-Hol': '23', 'Bst': 28.0, 'Rst': 14.0, 'Wgt': 6.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963458')}
# {'Weapon': "Envoy's Greathorn", 'Type': 'Colossal Weapon', 'Phy': 296.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 191.0, 'Cri': 100.0, 'Sta': 202.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '43', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '55', 'Bst': 40.0, 'Rst': 25.0, 'Wgt': 19.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963459')}
# {'Weapon': "Envoy's Horn", 'Type': 'Hammer', 'Phy': 235.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 151.0, 'Cri': 100.0, 'Sta': 106.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '38', 'def-Mag': '26', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '38', 'Bst': 28.0, 'Rst': 14.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796345a')}
# {'Weapon': "Envoy's Long Horn", 'Type': 'Great Hammer', 'Phy': 294.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 191.0, 'Cri': 100.0, 'Sta': 154.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '42', 'Bst': 33.0, 'Rst': 19.0, 'Wgt': 9.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796345b')}
# {'Weapon': 'Erdsteel Dagger', 'Type': 'Dagger', 'Phy': 164.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 110.0, 'Sta': 60.0, 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '21', 'def-Fir': '21', 'def-Lit': '21', 'def-Hol': '21', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 2.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796345c')}
# {'Weapon': 'Erdtree Bow', 'Type': 'Bow', 'Phy': 98.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 122.0, 'Cri': 100.0, 'Sta': 60.0, 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796345d')}
# {'Weapon': 'Erdtree Greatbow', 'Type': 'Greatbow', 'Phy': 147.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 159.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 11.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796345e')}
# {'Weapon': 'Erdtree Seal', 'Type': 'Sacred Seal', 'Phy': 61.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 36.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 0.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796345f')}
# {'Weapon': 'Estoc', 'Type': 'Thrusting Sword', 'Phy': 262.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 66.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 28.0, 'Rst': 12.0, 'Wgt': 4.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963460')}
# {'Weapon': "Executioner's Greataxe", 'Type': 'Greataxe', 'Phy': 367.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 115.0, 'Sta': 172.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '57', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': 48.0, 'Rst': 23.0, 'Wgt': 15.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963461')}
# {'Weapon': 'Falchion', 'Type': 'Curved Sword', 'Phy': 267.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '42', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 31.0, 'Rst': 10.0, 'Wgt': 3.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963462')}
# {'Weapon': 'Fallingstar Beast Jaw', 'Type': 'Colossal Weapon', 'Phy': 320.0, 'Mag': 208.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 180.0, 'Str': 'C', 'Dex': 'C', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '55', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': 40.0, 'Rst': 25.0, 'Wgt': 21.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963463')}
# {'Weapon': 'Family Heads', 'Type': 'Flail', 'Phy': 213.0, 'Mag': 137.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 106.0, 'Str': 'D', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '37', 'def-Mag': '36', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '26', 'Bst': 20.0, 'Rst': 15.0, 'Wgt': 5.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963464')}
# {'Weapon': 'Finger Seal', 'Type': 'Sacred Seal', 'Phy': 43.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'D', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 1.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963465')}
# {'Weapon': 'Flail', 'Type': 'Flail', 'Phy': 267.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 112.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '36', 'def-Mag': '24', 'def-Fir': '24', 'def-Lit': '24', 'def-Hol': '24', 'Bst': 24.0, 'Rst': 15.0, 'Wgt': 5.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963466')}
# {'Weapon': 'Flamberge', 'Type': 'Greatsword', 'Phy': 316.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 118.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 20.0, 'Wgt': 10.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963467')}
# {'Weapon': 'Flowing Curved Sword', 'Type': 'Curved Sword', 'Phy': 267.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '42', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 31.0, 'Rst': 10.0, 'Wgt': 3.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963468')}
# {'Weapon': 'Forked Greatsword', 'Type': 'Greatsword', 'Phy': 303.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 112.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 39.0, 'Rst': 19.0, 'Wgt': 9.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963469')}
# {'Weapon': 'Forked Hatchet', 'Type': 'Axe', 'Phy': 247.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 106.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '40', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 32.0, 'Rst': 13.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796346a')}
# {'Weapon': 'Frenzied Flame Seal', 'Type': 'Sacred Seal', 'Phy': 61.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 40.0, 'Str': 'C', 'Dex': 'C', 'Int': 'C', 'Fai': 'B', 'Arc': '0', 'Any': '(55)', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 0.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796346b')}
# {'Weapon': 'Frozen Needle', 'Type': 'Thrusting Sword', 'Phy': 242.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 60.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(60)', 'def-Phy': '40', 'def-Mag': '40', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': 20.0, 'Rst': 10.0, 'Wgt': 2.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796346c')}
# {'Weapon': 'Full Moon Crossbow', 'Type': 'Crossbow', 'Phy': 175.0, 'Mag': 175.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 60.0, 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': 0.0, 'Rst': 0.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796346d')}
# {'Weapon': "Gargoyle's Black Axe", 'Type': 'Greataxe', 'Phy': 245.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 294.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'C', 'Dex': 'E', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '54', 'Bst': 31.0, 'Rst': 18.0, 'Wgt': 8.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796346e')}
# {'Weapon': "Gargoyle's Black Blades", 'Type': 'Twinblade', 'Phy': 198.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 237.0, 'Cri': 100.0, 'Sta': 100.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '32', 'def-Mag': '26', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '59', 'Bst': 32.0, 'Rst': 16.0, 'Wgt': 8.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af796346f')}
# {'Weapon': "Gargoyle's Black Halberd", 'Type': 'Halberd', 'Phy': 252.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 301.0, 'Cri': 100.0, 'Sta': 152.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '72', 'Bst': 42.0, 'Rst': 18.0, 'Wgt': 12.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963470')}
# {'Weapon': "Gargoyle's Blackblade", 'Type': 'Greatsword', 'Phy': 249.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 298.0, 'Cri': 100.0, 'Sta': 138.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '66', 'Bst': 38.0, 'Rst': 22.0, 'Wgt': 11.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963471')}
# {'Weapon': "Gargoyle's Great Axe", 'Type': 'Greataxe', 'Phy': 301.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 37.0, 'Rst': 18.0, 'Wgt': 8.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963472')}
# {'Weapon': "Gargoyle's Greatsword", 'Type': 'Greatsword', 'Phy': 325.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 138.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '38', 'def-Fir': '38', 'def-Lit': '38', 'def-Hol': '38', 'Bst': 45.0, 'Rst': 22.0, 'Wgt': 11.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963473')}
# {'Weapon': "Gargoyle's Halberd", 'Type': 'Halberd', 'Phy': 320.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 152.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '42', 'def-Fir': '42', 'def-Lit': '42', 'def-Hol': '42', 'Bst': 50.0, 'Rst': 18.0, 'Wgt': 12.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963474')}
# {'Weapon': "Gargoyle's Twinblade", 'Type': 'Twinblade', 'Phy': 301.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 100.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '32', 'def-Fir': '32', 'def-Lit': '32', 'def-Hol': '32', 'Bst': 38.0, 'Rst': 16.0, 'Wgt': 8.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963475')}
# {'Weapon': 'Gelmir Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': 50.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 38.0, 'Str': 'D', 'Dex': '0', 'Int': 'B', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': 14.0, 'Rst': 9.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963476')}
# {'Weapon': "Ghiza's Wheel", 'Type': 'Colossal Weapon', 'Phy': 382.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 184.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(70)', 'def-Phy': '58', 'def-Mag': '43', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': 39.0, 'Rst': 24.0, 'Wgt': 19.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963477')}
# {'Weapon': 'Ghostflame Torch', 'Type': 'Torch', 'Phy': 122.0, 'Mag': 220.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 104.0, 'Str': 'D', 'Dex': 'D', 'Int': 'C', 'Fai': '0', 'Arc': '0', 'Any': '(65)', 'def-Phy': '21', 'def-Mag': '42', 'def-Fir': '13', 'def-Lit': '13', 'def-Hol': '13', 'Bst': 22.0, 'Rst': 14.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963478')}
# {'Weapon': "Giant's Red Braid", 'Type': 'Whip', 'Phy': 200.0, 'Mag': 0.0, 'Fir': 129.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 88.0, 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '24', 'def-Mag': '12', 'def-Fir': '26', 'def-Lit': '12', 'def-Hol': '12', 'Bst': 15.0, 'Rst': 10.0, 'Wgt': 2.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb41f0e4ff9af7963479')}
# ...
# {'Weapon': 'Star Fist', 'Type': 'Fist', 'Phy': 257.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 112.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(45)', 'def-Phy': '41', 'def-Mag': '23', 'def-Fir': '23', 'def-Lit': '23', 'def-Hol': '23', 'Bst': 27.0, 'Rst': 11.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963515')}
# {'Weapon': 'Starscourge Greatsword', 'Type': 'Colossal Sword', 'Phy': 316.0, 'Mag': 203.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 156.0, 'Str': 'B', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '47', 'def-Fir': '34', 'def-Lit': '34', 'def-Hol': '34', 'Bst': 42.0, 'Rst': 26.0, 'Wgt': 20.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963516')}
# {'Weapon': 'Steel-Wire Torch', 'Type': 'Torch', 'Phy': 149.0, 'Mag': 0.0, 'Fir': 267.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 104.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '18', 'def-Fir': '30', 'def-Lit': '18', 'def-Hol': '18', 'Bst': 24.0, 'Rst': 15.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963517')}
# {'Weapon': 'Stone Club', 'Type': 'Hammer', 'Phy': 298.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 130.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 17.0, 'Wgt': 7.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963518')}
# {'Weapon': 'Stormhawk Axe', 'Type': 'Axe', 'Phy': 318.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 116.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 33.0, 'Rst': 16.0, 'Wgt': 5.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963519')}
# {'Weapon': 'Sword of Milos', 'Type': 'Greatsword', 'Phy': 345.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 126.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': 36.0, 'Rst': 21.0, 'Wgt': 10.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796351a')}
# {'Weapon': 'Sword of Night and Flame', 'Type': 'Straight Sword', 'Phy': 213.0, 'Mag': 137.0, 'Fir': 137.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'D', 'Dex': 'D', 'Int': 'B', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '42', 'def-Fir': '42', 'def-Lit': '26', 'def-Hol': '26', 'Bst': 31.0, 'Rst': 15.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796351b')}
# {'Weapon': 'Sword of St. Trina', 'Type': 'Straight Sword', 'Phy': 262.0, 'Mag': 78.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': 'D', 'Dex': 'C', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '(66)', 'def-Phy': '39', 'def-Mag': '33', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 28.0, 'Rst': 14.0, 'Wgt': 3.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796351c')}
# {'Weapon': 'Thorned Whip', 'Type': 'Whip', 'Phy': 249.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 84.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '26', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796351d')}
# {'Weapon': 'Torch', 'Type': 'Torch', 'Phy': 132.0, 'Mag': 0.0, 'Fir': 237.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 84.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '21', 'def-Mag': '15', 'def-Fir': '25', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 20.0, 'Rst': 12.0, 'Wgt': 1.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796351e')}
# {'Weapon': 'Torchpole', 'Type': 'Spear', 'Phy': 254.0, 'Mag': 0.0, 'Fir': 75.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 72.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '26', 'def-Fir': '33', 'def-Lit': '26', 'def-Hol': '26', 'Bst': 39.0, 'Rst': 16.0, 'Wgt': 6.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796351f')}
# {'Weapon': 'Treespear', 'Type': 'Great Spear', 'Phy': 298.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 193.0, 'Cri': 100.0, 'Sta': 122.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '48', 'Bst': 44.0, 'Rst': 21.0, 'Wgt': 9.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963520')}
# {'Weapon': "Troll Knight's Sword", 'Type': 'Colossal Sword', 'Phy': 303.0, 'Mag': 196.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'C', 'Dex': 'C', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '55', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': 40.0, 'Rst': 25.0, 'Wgt': 18.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963521')}
# {'Weapon': "Troll's Golden Sword", 'Type': 'Colossal Sword', 'Phy': 379.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 152.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '61', 'def-Mag': '46', 'def-Fir': '46', 'def-Lit': '46', 'def-Hol': '46', 'Bst': 49.0, 'Rst': 25.0, 'Wgt': 19.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963522')}
# {'Weapon': "Troll's Hammer", 'Type': 'Colossal Weapon', 'Phy': 374.0, 'Mag': 0.0, 'Fir': 110.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 184.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '41', 'def-Fir': '46', 'def-Lit': '41', 'def-Hol': '41', 'Bst': 44.0, 'Rst': 23.0, 'Wgt': 16.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963523')}
# {'Weapon': 'Twinblade', 'Type': 'Twinblade', 'Phy': 291.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': 36.0, 'Rst': 15.0, 'Wgt': 7.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963524')}
# {'Weapon': 'Twinned Knight Swords', 'Type': 'Twinblade', 'Phy': 298.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 94.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': 37.0, 'Rst': 15.0, 'Wgt': 8.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963525')}
# {'Weapon': 'Uchigatana', 'Type': 'Katana', 'Phy': 281.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(45)', 'def-Phy': '45', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': 36.0, 'Rst': 15.0, 'Wgt': 5.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963526')}
# {'Weapon': 'Urumi', 'Type': 'Whip', 'Phy': 247.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 92.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '27', 'def-Mag': '16', 'def-Fir': '16', 'def-Lit': '16', 'def-Hol': '16', 'Bst': 19.0, 'Rst': 11.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963527')}
# {'Weapon': "Varre's Bouquet", 'Type': 'Hammer', 'Phy': 112.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 100.0, 'Str': 'E', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': 'B', 'Any': '(65)', 'def-Phy': '38', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': 25.0, 'Rst': 12.0, 'Wgt': 2.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963528')}
# {'Weapon': 'Venomous Fang', 'Type': 'Claw', 'Phy': 225.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 78.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(72)', 'def-Phy': '36', 'def-Mag': '21', 'def-Fir': '21', 'def-Lit': '21', 'def-Hol': '21', 'Bst': 25.0, 'Rst': 10.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963529')}
# {'Weapon': "Veteran's Prosthesis", 'Type': 'Fist', 'Phy': 203.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 129.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 110.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '30', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '48', 'def-Hol': '20', 'Bst': 24.0, 'Rst': 12.0, 'Wgt': 4.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796352a')}
# {'Weapon': 'Vulgar Militia Saw', 'Type': 'Halberd', 'Phy': 308.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 128.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 15.0, 'Wgt': 8.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796352b')}
# {'Weapon': 'Vulgar Militia Shotel', 'Type': 'Halberd', 'Phy': 296.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 128.0, 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 42.0, 'Rst': 15.0, 'Wgt': 8.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796352c')}
# {'Weapon': "Vyke's War Spear", 'Type': 'Great Spear', 'Phy': 252.0, 'Mag': 0.0, 'Fir': 161.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 122.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '(65)', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '45', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 35.0, 'Rst': 20.0, 'Wgt': 8.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796352d')}
# {'Weapon': 'Wakizashi', 'Type': 'Dagger', 'Phy': 230.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 66.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(38)', 'def-Phy': '42', 'def-Mag': '24', 'def-Fir': '24', 'def-Lit': '24', 'def-Hol': '24', 'Bst': 21.0, 'Rst': 12.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796352e')}
# {'Weapon': "Warhawk's Talon", 'Type': 'Straight Sword', 'Phy': 247.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 84.0, 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '42', 'def-Mag': '28', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': 33.0, 'Rst': 14.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796352f')}
# {'Weapon': 'Warped Axe', 'Type': 'Greataxe', 'Phy': 289.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 128.0, 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '56', 'def-Mag': '37', 'def-Fir': '37', 'def-Lit': '37', 'def-Hol': '37', 'Bst': 51.0, 'Rst': 18.0, 'Wgt': 7.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963530')}
# {'Weapon': 'Warpick', 'Type': 'Hammer', 'Phy': 264.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 106.0, 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '40', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': 32.0, 'Rst': 13.0, 'Wgt': 2.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963531')}
# {'Weapon': "Watchdog's Greatsword", 'Type': 'Colossal Sword', 'Phy': 347.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 164.0, 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '66', 'def-Mag': '49', 'def-Fir': '49', 'def-Lit': '49', 'def-Hol': '49', 'Bst': 45.0, 'Rst': 27.0, 'Wgt': 22.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963532')}
# {'Weapon': "Watchdog's Staff", 'Type': 'Colossal Weapon', 'Phy': 404.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 200.0, 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '45', 'def-Fir': '45', 'def-Lit': '45', 'def-Hol': '45', 'Bst': 40.0, 'Rst': 25.0, 'Wgt': 19.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963533')}
# {'Weapon': 'Weathered Straight Sword', 'Type': 'Straight Sword', 'Phy': 252.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 90.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '43', 'def-Mag': '29', 'def-Fir': '29', 'def-Lit': '29', 'def-Hol': '29', 'Bst': 34.0, 'Rst': 14.0, 'Wgt': 3.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963534')}
# {'Weapon': 'Whip', 'Type': 'Whip', 'Phy': 245.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 84.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': 18.0, 'Rst': 10.0, 'Wgt': 2.0, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963535')}
# {'Weapon': 'Wing of Astel', 'Type': 'Curved Sword', 'Phy': 159.0, 'Mag': 191.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 84.0, 'Str': 'E', 'Dex': 'C', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '28', 'def-Mag': '52', 'def-Fir': '23', 'def-Lit': '23', 'def-Hol': '23', 'Bst': 23.0, 'Rst': 9.0, 'Wgt': 2.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963536')}
# {'Weapon': 'Winged Greathorn', 'Type': 'Greataxe', 'Phy': 318.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 150.0, 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': 35.0, 'Rst': 20.0, 'Wgt': 11.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963537')}
# {'Weapon': 'Winged Scythe', 'Type': 'Reaper', 'Phy': 213.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 254.0, 'Cri': 100.0, 'Sta': 110.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '(55)', 'def-Phy': '30', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '55', 'Bst': 30.0, 'Rst': 15.0, 'Wgt': 7.5, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963538')}
# {'Weapon': 'Zamor Curved Sword', 'Type': 'Curved Greatsword', 'Phy': 306.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 128.0, 'Str': 'C', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(65)', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': 33.0, 'Rst': 19.0, 'Wgt': 9.0, 'Upgrade': 'Somber Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af7963539')}
# {'Weapon': 'Zweihander', 'Type': 'Colossal Sword', 'Phy': 345.0, 'Mag': 0.0, 'Fir': 0.0, 'Lit': 0.0, 'Hol': 0.0, 'Cri': 100.0, 'Sta': 126.0, 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': 43.0, 'Rst': 22.0, 'Wgt': 15.5, 'Upgrade': 'Smithing Stones', '_id': ObjectId('6258bb42f0e4ff9af796353a')}

# %%
collection.drop("Weapon":)
# Out:
#   File "C:\Users\annam\AppData\Local\Temp/ipykernel_14208/2996874329.py", line 1
#     collection.drop("Weapon":)
#                             ^
# SyntaxError: invalid syntax
